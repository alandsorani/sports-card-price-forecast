# %% [markdown]
# # 02 — Exploratory analysis

# %%
import sys; sys.path.insert(0, '..')
import pandas as pd
from src.features.pipeline import build_panel, feature_columns
panel = build_panel(with_targets=False)
panel.groupby('card_id')['price'].describe()

# %%
import plotly.express as px
fig = px.line(panel, x='date', y='price', color='card_name', log_y=True)
fig.show()
