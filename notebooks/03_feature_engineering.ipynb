# %% [markdown]
# # 03 — Feature engineering
# All features are as-of the row date; see `docs` in `src/evaluation/leakage.py` for the audit.

# %%
import sys; sys.path.insert(0, '..')
import pandas as pd
from src.features.pipeline import build_panel, feature_columns
panel = build_panel()
feats = feature_columns(panel)
print(len(feats)); feats

# %%
panel[feats].describe().T
