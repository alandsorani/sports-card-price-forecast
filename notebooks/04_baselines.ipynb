# %% [markdown]
# # 04 — Baselines

# %%
import sys; sys.path.insert(0, '..')
import pandas as pd
from src.features.pipeline import build_panel, feature_columns
from src.models.baselines import baseline_predictions
from src.evaluation.metrics import compute_metrics
panel = build_panel()
labeled = panel.dropna(subset=['future_price_30d']).reset_index(drop=True)
for name, preds in baseline_predictions(labeled, 30).items():
    print(name, compute_metrics(labeled['future_price_30d'].values, preds.values, labeled['price'].values))
