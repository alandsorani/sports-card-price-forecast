# %% [markdown]
# # 05 — Modeling (walk-forward)

# %%
import sys; sys.path.insert(0, '..')
import pandas as pd
from src.features.pipeline import build_panel, feature_columns
from src.models.train import walk_forward, results_frame
panel = build_panel()
feats = feature_columns(panel)
res = walk_forward(panel, feats, 30)
frame = results_frame(res)
frame.groupby('model')[['mae','rmse','r2']].mean().sort_values('mae')
