# %% [markdown]
# # 06 — Backtest results
# Run `python backtest.py` first.

# %%
import pandas as pd
fc = pd.read_csv('../reports/backtest_forecasts.csv', parse_dates=['asof'])
metrics = pd.read_csv('../reports/backtest_metrics.csv')
metrics

# %%
import plotly.express as px
sub = fc[fc['horizon']==90].dropna(subset=['actual'])
px.scatter(sub, x='forecast', y='actual', hover_data=['card_id'], log_x=True, log_y=True)
