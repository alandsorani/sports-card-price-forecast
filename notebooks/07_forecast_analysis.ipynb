# %% [markdown]
# # 07 — Forecast analysis
# Run `python train.py` first.

# %%
import sys; sys.path.insert(0, '..')
import pandas as pd
from src.features.pipeline import build_panel, feature_columns
from src.forecasting.forecast import forecast_card
panel = build_panel()
cid = panel['card_id'].iloc[0]
fc = forecast_card(panel, cid)
fc.card_name, fc.current_price, fc.horizons, fc.reliability
